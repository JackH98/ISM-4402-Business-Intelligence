# %%
import pandas as pd

# %%
import numpy as np

# %%
Location = "C:/Users/jackh/Desktop/BI/datasets/gradedata.csv"
df = pd.read_csv(Location)
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#         fname       lname  gender  age  exercise  hours  grade  \
# 712       Jin       Parks    male   17         1      8   78.4
# 323   Jackson  Williamson    male   15         1     10   75.3
# 1799    Wanda       Jones  female   16         3     14   84.7
# 1118    Clare      Clarke  female   19         3      8   74.0
# 76     Deanna      Warren  female   19         1      9   83.2
# ...       ...         ...     ...  ...       ...    ...    ...
# 1354    Regan    Hatfield  female   14         4     12   81.1
# 1596  Matthew  Washington    male   17         2     13   85.7
# 1051   Lucius        Vang    male   15         3     10   80.6
# 559      Wang      Dorsey    male   18         3     10   76.3
# 507    Travis       Avery    male   15         4     12   85.1
#
#                                                 address
# 712                  63 Willow Street, Mobile, AL 36605
# 323                54 Bridle Drive, Hephzibah, GA 30815
# ...
